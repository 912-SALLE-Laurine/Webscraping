# %%
import requests
import pandas as pd
import json

# %%
url = "https://data.enedis.fr/api/v2/catalog/datasets/bilan-electrique-transpose/records?sort=jour"
payload={}
headers = {}
total_count_response = requests.request("GET", url, headers=headers, data=payload)
total_count = int(total_count_response.json()["total_count"])
print(total_count)
# Out:
# 10956

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# results will be appended to this list
all_items = []

response_df = pd.DataFrame()

# loop through all offset and return JSON object
for offset in range(0, total_count, 100):

    url = "https://data.enedis.fr/api/v2/catalog/datasets/bilan-electrique-transpose/records?sort=jour&limit=100&offset="+str(offset)              
    response = requests.get(url=url, headers=headers) 
    for element in json.loads(response.text)["records"]:
        response_df = response_df.append(element["record"]["fields"], ignore_index=True)
    print(offset)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44400\2645236230.py in <module>
# ...

# %%
response_df.shape
# Out:
# (9900, 3)

# %%
response_df.tail(30)
# Out:
#             jour                                          categorie  \
# 9870  2022-05-29                                        Entreprises
# 9871  2022-05-29  Puissance moyenne journalière des consommation...
# 9872  2022-05-29                                     Professionnels
# 9873  2022-05-29                                          PME / PMI
# 9874  2022-05-29                                       Résidentiels
# 9875  2022-05-29  Puissance moyenne journalière des consommation...
# 9876  2022-05-30  Puissance moyenne journalière des consommation...
# 9877  2022-05-30  Puissance moyenne journalière des consommation...
# 9878  2022-05-30                                       Résidentiels
# 9879  2022-05-30                                     Professionnels
# 9880  2022-05-30                                          PME / PMI
# 9881  2022-05-30                                        Entreprises
# 9882  2022-05-31                                       Résidentiels
# ...

# %%
response_df.head(20)
# Out:
#           jour                                          categorie  \
# 0   2017-11-26  Puissance moyenne journalière des consommation...
# 1   2017-11-26                                          PME / PMI
# 2   2017-11-26                                        Entreprises
# 3   2017-11-26                                       Résidentiels
# 4   2017-11-26  Puissance moyenne journalière des consommation...
# 5   2017-11-26                                     Professionnels
# 6   2017-11-27  Puissance moyenne journalière des consommation...
# 7   2017-11-27                                     Professionnels
# 8   2017-11-27                                       Résidentiels
# 9   2017-11-27                                          PME / PMI
# 10  2017-11-27                                        Entreprises
# 11  2017-11-27  Puissance moyenne journalière des consommation...
# 12  2017-11-28                                       Résidentiels
# ...

# %%
response_df["annee"] = response_df["jour"].str[:4]
response_df["date"] = response_df["jour"].str[5:]

# %%
# write to csv
response_df.to_csv("enedis2.csv", index=False)
